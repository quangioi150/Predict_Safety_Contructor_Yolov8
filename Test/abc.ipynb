# %%
import cv2
from ultralytics import YOLO
import numpy as np

# cap = cv2.VideoCapture("video.mp4")
model = YOLO("yolov8n.pt")
cap = cv2.VideoCapture("test.mp4")
# model = YOLO("best.pt")
while True:
    ret, frame = cap.read()
    if not ret:
        break
    results = model.track(frame, persist=True)
    # results = torch(results[0])
    boxes = np.array(results[0].boxes.xyxy).astype(int)
    ids = np.array(results[0].boxes.id).astype(int)
    # ids = None
    print(ids)
    for box, id in zip(boxes, ids):
        cv2.rectangle(frame, (box[0], box[1]), (box[2], box[3]), (0, 255, 0), 2)
        cv2.putText(
            frame,
            f"Id {id}",
            (box[0], box[1]),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 0, 255),
            2,
        )
    cv2.imshow("frame", frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break
# Out:
# 0: 384x640 (no detections), 193.4ms
# Speed: 2.0ms preprocess, 193.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 16
#      14 # results = torch(results[0])
#      15 boxes = np.array(results[0].boxes.xyxy).astype(int)
# ---> 16 ids = np.array(results[0].boxes.id).astype(int)
#      17 # ids = None
#      18 print(ids)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %%
 results = model.track(frame, persist=True)

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model.track(source="https://youtu.be/Zgi9g1ksQHc", tracker='custom_tracker.yaml')
# Out:
# ERROR: Unable to download API page: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)> (caused by URLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Users\ADMIN\miniconda3\lib\urllib\request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1345 try:
# -> 1346     h.request(req.get_method(), req.selector, req.data, headers,
#    1347               encode_chunked=req.has_header('Transfer-encoding'))
#    1348 except OSError as err: # timeout error
#
# File c:\Users\ADMIN\miniconda3\lib\http\client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\ADMIN\miniconda3\lib\http\client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\Users\ADMIN\miniconda3\lib\http\client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\ADMIN\miniconda3\lib\http\client.py:1040, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 del self._buffer[:]
# -> 1040 self.send(msg)
#    1042 if message_body is not None:
#    1043
#    1044     # create a consistent interface to message_body
#
# File c:\Users\ADMIN\miniconda3\lib\http\client.py:980, in HTTPConnection.send(self, data)
#     979 if self.auto_open:
# --> 980     self.connect()
#     981 else:
#
# File c:\Users\ADMIN\miniconda3\lib\http\client.py:1454, in HTTPSConnection.connect(self)
#    1452     server_hostname = self.host
# -> 1454 self.sock = self._context.wrap_socket(self.sock,
#    1455                                       server_hostname=server_hostname)
#
# File c:\Users\ADMIN\miniconda3\lib\ssl.py:501, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     495 def wrap_socket(self, sock, server_side=False,
#     496                 do_handshake_on_connect=True,
#     497                 suppress_ragged_eofs=True,
#     498                 server_hostname=None, session=None):
#     499     # SSLSocket class handles server_hostname encoding before it calls
#     500     # ctx._wrap_socket()
# --> 501     return self.sslsocket_class._create(
#     502         sock=sock,
#     503         server_side=server_side,
#     504         do_handshake_on_connect=do_handshake_on_connect,
#     505         suppress_ragged_eofs=suppress_ragged_eofs,
#     506         server_hostname=server_hostname,
#     507         context=self,
#     508         session=session
#     509     )
#
# File c:\Users\ADMIN\miniconda3\lib\ssl.py:1041, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1040             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041         self.do_handshake()
#    1042 except (OSError, ValueError):
#
# File c:\Users\ADMIN\miniconda3\lib\ssl.py:1310, in SSLSocket.do_handshake(self, block)
#    1309         self.settimeout(None)
# -> 1310     self._sslobj.do_handshake()
#    1311 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\extractor\common.py:634, in InfoExtractor._request_webpage(self, url_or_request, video_id, note, errnote, fatal, data, headers, query, expected_status)
#     633 try:
# --> 634     return self._downloader.urlopen(url_or_request)
#     635 except tuple(exceptions) as err:
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\YoutubeDL.py:2288, in YoutubeDL.urlopen(self, req)
#    2287     req = sanitized_Request(req)
# -> 2288 return self._opener.open(req, timeout=self._socket_timeout)
#
# File c:\Users\ADMIN\miniconda3\lib\urllib\request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#
# File c:\Users\ADMIN\miniconda3\lib\urllib\request.py:534, in OpenerDirector._open(self, req, data)
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#
# File c:\Users\ADMIN\miniconda3\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     493 func = getattr(handler, meth_name)
# --> 494 result = func(*args)
#     495 if result is not None:
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\utils.py:2735, in YoutubeDLHTTPSHandler.https_open(self, req)
#    2733     del req.headers['Ytdl-socks-proxy']
# -> 2735 return self.do_open(functools.partial(
#    2736     _create_http_connection, self, conn_class, True),
#    2737     req, **kwargs)
#
# File c:\Users\ADMIN\miniconda3\lib\urllib\request.py:1349, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348 except OSError as err: # timeout error
# -> 1349     raise URLError(err)
#    1350 r = h.getresponse()
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)>
#
# During handling of the above exception, another exception occurred:
#
# ExtractorError                            Traceback (most recent call last)
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\YoutubeDL.py:815, in YoutubeDL.__handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#     814 try:
# --> 815     return func(self, *args, **kwargs)
#     816 except GeoRestrictedError as e:
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\YoutubeDL.py:836, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#     834 @__handle_extraction_exceptions
#     835 def __extract_info(self, url, ie, download, extra_info, process):
# --> 836     ie_result = ie.extract(url)
#     837     if ie_result is None:  # Finished already (backwards compatibility; listformats and friends should be moved here)
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\extractor\common.py:534, in InfoExtractor.extract(self, url)
#     533 self.initialize()
# --> 534 ie_result = self._real_extract(url)
#     535 if self._x_forwarded_for_ip:
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\extractor\youtube.py:1502, in YoutubeIE._real_extract(self, url)
#    1501 if not player_response:
# -> 1502     player_response = self._call_api(
#    1503         'player', {'videoId': video_id}, video_id)
#    1505 playability_status = player_response.get('playabilityStatus') or {}
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\extractor\youtube.py:290, in YoutubeBaseInfoExtractor._call_api(self, ep, query, video_id, fatal)
#     288 data.update(query)
# --> 290 return self._download_json(
#     291     'https://www.youtube.com/youtubei/v1/%s' % ep, video_id=video_id,
#     292     note='Downloading API JSON', errnote='Unable to download API page',
#     293     data=json.dumps(data).encode('utf8'), fatal=fatal,
#     294     headers={'content-type': 'application/json'},
#     295     query={'key': 'AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8'})
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\extractor\common.py:895, in InfoExtractor._download_json(self, url_or_request, video_id, note, errnote, transform_source, fatal, encoding, data, headers, query, expected_status)
#     890 """
#     891 Return the JSON object as a dict.
#     892
#     893 See _download_webpage docstring for arguments specification.
#     894 """
# --> 895 res = self._download_json_handle(
#     896     url_or_request, video_id, note=note, errnote=errnote,
#     897     transform_source=transform_source, fatal=fatal, encoding=encoding,
#     898     data=data, headers=headers, query=query,
#     899     expected_status=expected_status)
#     900 return res if res is False else res[0]
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\extractor\common.py:874, in InfoExtractor._download_json_handle(self, url_or_request, video_id, note, errnote, transform_source, fatal, encoding, data, headers, query, expected_status)
#     869 """
#     870 Return a tuple (JSON object, URL handle).
#     871
#     872 See _download_webpage docstring for arguments specification.
#     873 """
# --> 874 res = self._download_webpage_handle(
#     875     url_or_request, video_id, note, errnote, fatal=fatal,
#     876     encoding=encoding, data=data, headers=headers, query=query,
#     877     expected_status=expected_status)
#     878 if res is False:
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\extractor\common.py:667, in InfoExtractor._download_webpage_handle(self, url_or_request, video_id, note, errnote, fatal, encoding, data, headers, query, expected_status)
#     665     url_or_request = url_or_request.partition('#')[0]
# --> 667 urlh = self._request_webpage(url_or_request, video_id, note, errnote, fatal, data=data, headers=headers, query=query, expected_status=expected_status)
#     668 if urlh is False:
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\extractor\common.py:652, in InfoExtractor._request_webpage(self, url_or_request, video_id, note, errnote, fatal, data, headers, query, expected_status)
#     651 if fatal:
# --> 652     raise ExtractorError(errmsg, sys.exc_info()[2], cause=err)
#     653 else:
#
# ExtractorError: Unable to download API page: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)> (caused by URLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# DownloadError                             Traceback (most recent call last)
# File c:\Users\ADMIN\miniconda3\lib\site-packages\pafy\backend_youtube_dl.py:40, in YtdlPafy._fetch_basic(self)
#      39 try:
# ---> 40     self._ydl_info = ydl.extract_info(self.videoid, download=False)
#      41 # Turn into an IOError since that is what pafy previously raised
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\YoutubeDL.py:808, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#     805         self.report_warning('The program functionality for this site has been marked as broken, '
#     806                             'and will probably not work.')
# --> 808     return self.__extract_info(url, ie, download, extra_info, process)
#     809 else:
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\YoutubeDL.py:824, in YoutubeDL.__handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#     823 except ExtractorError as e:  # An error we somewhat expected
# --> 824     self.report_error(compat_str(e), e.format_traceback())
#     825 except MaxDownloadsReached:
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\YoutubeDL.py:628, in YoutubeDL.report_error(self, message, tb)
#     627 error_message = '%s %s' % (_msg_header, message)
# --> 628 self.trouble(error_message, tb)
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\youtube_dl\YoutubeDL.py:598, in YoutubeDL.trouble(self, message, tb)
#     597         exc_info = sys.exc_info()
# --> 598     raise DownloadError(message, exc_info)
#     599 self._download_retcode = 1
#
# DownloadError: ERROR: Unable to download API page: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)> (caused by URLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[20], line 5
#       1 from ultralytics import YOLO
#       3 model = YOLO("yolov8n.pt")
# ----> 5 results = model.track(source="https://youtu.be/Zgi9g1ksQHc", tracker='custom_tracker.yaml')
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\ultralytics\yolo\engine\model.py:275, in YOLO.track(self, source, stream, persist, **kwargs)
#     273 kwargs['conf'] = conf
#     274 kwargs['mode'] = 'track'
# --> 275 return self.predict(source=source, stream=stream, **kwargs)
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\torch\autograd\grad_mode.py:28, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      25 @functools.wraps(func)
#      26 def decorate_context(*args, **kwargs):
#      27     with self.__class__():
# ---> 28         return func(*args, **kwargs)
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\ultralytics\yolo\engine\model.py:252, in YOLO.predict(self, source, stream, **kwargs)
#     250 else:  # only update args if predictor is already setup
#     251     self.predictor.args = get_cfg(self.predictor.args, overrides)
# --> 252 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\ultralytics\yolo\engine\predictor.py:174, in BasePredictor.__call__(self, source, model, stream)
#     172     return self.stream_inference(source, model)
#     173 else:
# --> 174     return list(self.stream_inference(source, model))
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\torch\autograd\grad_mode.py:45, in _DecoratorContextManager._wrap_generator.<locals>.generator_context(*args, **kwargs)
#      42 try:
#      43     # Issuing `None` to a generator fires it up
#      44     with cls():
# ---> 45         response = gen.send(None)
#      47     while True:
#      48         try:
#      49             # Forward the response to our caller and get its next request
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\ultralytics\yolo\engine\predictor.py:205, in BasePredictor.stream_inference(self, source, model)
#     203     self.setup_model(model)
#     204 # Setup source every time predict is called
# --> 205 self.setup_source(source if source is not None else self.args.source)
#     207 # Check if save_dir/ label file exists
#     208 if self.args.save or self.args.save_txt:
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\ultralytics\yolo\engine\predictor.py:187, in BasePredictor.setup_source(self, source)
#     184 self.imgsz = check_imgsz(self.args.imgsz, stride=self.model.stride, min_dim=2)  # check image size
#     185 self.transforms = getattr(self.model.model, 'transforms', classify_transforms(
#     186     self.imgsz[0])) if self.args.task == 'classify' else None
# --> 187 self.dataset = load_inference_source(source=source, imgsz=self.imgsz, vid_stride=self.args.vid_stride)
#     188 self.source_type = self.dataset.source_type
#     189 if not getattr(self, 'stream', True) and (self.dataset.mode == 'stream' or  # streams
#     190                                           len(self.dataset) > 1000 or  # images
#     191                                           any(getattr(self.dataset, 'video_flag', [False]))):  # videos
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\ultralytics\yolo\data\build.py:159, in load_inference_source(source, imgsz, vid_stride)
#     157     dataset = source
#     158 elif webcam:
# --> 159     dataset = LoadStreams(source, imgsz=imgsz, vid_stride=vid_stride)
#     160 elif screenshot:
#     161     dataset = LoadScreenshots(source, imgsz=imgsz)
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\ultralytics\yolo\data\dataloaders\stream_loaders.py:50, in LoadStreams.__init__(self, sources, imgsz, vid_stride)
#      48     check_requirements(('pafy', 'youtube_dl==2020.12.2'))
#      49     import pafy  # noqa
# ---> 50     s = pafy.new(s).getbest(preftype='mp4').url  # YouTube URL
#      51 s = eval(s) if s.isnumeric() else s  # i.e. s = '0' local webcam
#      52 if s == 0 and (is_colab() or is_kaggle()):
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\pafy\pafy.py:124, in new(url, basic, gdata, size, callback, ydl_opts)
#     121     else:
#     122        from .backend_youtube_dl import YtdlPafy as Pafy
# --> 124 return Pafy(url, basic, gdata, size, callback, ydl_opts=ydl_opts)
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\pafy\backend_youtube_dl.py:31, in YtdlPafy.__init__(self, *args, **kwargs)
#      29 if ydl_opts:
#      30     self._ydl_opts.update(ydl_opts)
# ---> 31 super(YtdlPafy, self).__init__(*args, **kwargs)
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\pafy\backend_shared.py:97, in BasePafy.__init__(self, video_url, basic, gdata, size, callback, ydl_opts)
#      94 self.expiry = None
#      96 if basic:
# ---> 97     self._fetch_basic()
#      99 if gdata:
#     100     self._fetch_gdata()
#
# File c:\Users\ADMIN\miniconda3\lib\site-packages\pafy\backend_youtube_dl.py:43, in YtdlPafy._fetch_basic(self)
#      41     # Turn into an IOError since that is what pafy previously raised
#      42     except youtube_dl.utils.DownloadError as e:
# ---> 43         raise IOError(str(e).replace('YouTube said', 'Youtube says'))
#      45 if self.callback:
#      46     self.callback("Fetched video info")
#
# OSError: ERROR: Unable to download API page: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)> (caused by URLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
